# %% [markdown]
# <a href="https://colab.research.google.com/github/richiv4r3-crypto/MineriaDeDatos/blob/main/4.largest_islands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World's largest islands
#
# This dataset `largest-islands.csv` contains information about the 100 largest islands in the world. The unit for the `area` column is km2.

# %%
# FOR GOOGLE COLAB ONLY.
# Uncomment and run the code below. A dialog will appear to upload files.
# Upload 'largest-islands.csv'.

# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('largest-islands.csv')
df.head()
# Out:
#       region      island    area                countries    climate  rank
# 0     Africa  Madagascar  591896               Madagascar    tropics     4
# 1  Antarctic   Kerguelen    6200  Antarctic Lands, France  temperate    91
# 2       Asia       Sumba   11153                Indonesia    tropics    65
# 3       Asia      Hainan   34300                    China    tropics    37
# 4       Asia      Taiwan   36198                   Taiwan    tropics    36

# %% [markdown]
# ### Project Ideas
#
# - What are the 10 largest islands in the tropics?
#
# - What are the largest islands in each `region`?
#
# - Create a line graph with `area` on the y-axis and `rank` on the x-axis. The data should be ordered by `rank`, from largest to smallest.
#
# - What islands are composed of multiple countries?
# 	- Hint: try `countries.str.contains(",")`

# %%
#1. What are the 10 largest islands in the tropics?
df.sort_values(by='area', ascending=False).head(10)
# Out:
#            region               island     area                    countries  \
# 41         Europe            Greenland  2166086                      Denmark
# 86        Oceania           New Guinea   821400  Papua New Guinea, Indonesia
# 23           Asia               Borneo   755000  Indonesia, Malaysia, Brunei
# 0          Africa           Madagascar   591896                   Madagascar
# 75  North America        Baffin Island   507451                       Canada
# 28           Asia              Sumatra   480793                    Indonesia
# 27           Asia               Honshu   227898                        Japan
# 69  North America      Victoria Island   217291                       Canada
# 43         Europe        Great Britain   209331               United Kingdom
# 83  North America  Ellesmere (Nunavut)   196236                       Canada
#
#       climate  rank
# 41      polar     1
# 86    tropics     2
# 23    tropics     3
# 0     tropics     4
# ...

# %%
# 2.What are the largest islands in each region?
#df['region'].drop_duplicates()

# %%
df.query('region == "Africa"').sort_values(by='area', ascending=False).head(1)
# Out:
#    region      island    area   countries  climate  rank
# 0  Africa  Madagascar  591896  Madagascar  tropics     4

# %%
df.query('region == "Antarctic"').sort_values(by='area', ascending=False).head(1)
# Out:
#       region     island  area                countries    climate  rank
# 1  Antarctic  Kerguelen  6200  Antarctic Lands, France  temperate    91

# %%
df.query('region == "Asia"').sort_values(by='area', ascending=False).head(1)
# Out:
#    region  island    area                    countries  climate  rank
# 23   Asia  Borneo  755000  Indonesia, Malaysia, Brunei  tropics     3

# %%
df.query('region == "Eurasia"').sort_values(by='area', ascending=False).head(1)
# Out:
#      region    island   area countries    climate  rank
# 35  Eurasia  Sakhalin  76400    Russia  temperate    22

# %%
df.query('region == "Europe"').sort_values(by='area', ascending=False).head(1)
# Out:
#     region     island     area countries climate  rank
# 41  Europe  Greenland  2166086   Denmark   polar     1

# %%
df.query('region == "North America"').sort_values(by='area', ascending=False).head(1)
# Out:
#            region         island    area countries climate  rank
# 75  North America  Baffin Island  507451    Canada   polar     5

# %%
df.query('region == "Oceania"').sort_values(by='area', ascending=False).head(1)
# Out:
#      region      island    area                    countries  climate  rank
# 86  Oceania  New Guinea  821400  Papua New Guinea, Indonesia  tropics     2

# %%
df.query('region == "South America"').sort_values(by='area', ascending=False).head(1)
# Out:
#            region                           island   area         countries  \
# 98  South America  Isla Grande de Tierra del Fuego  47992  Chile, Argentina
#
#       climate  rank
# 98  temperate    28

# %%
#Create a line graph with area on the y-axis and rank on the x-axis. The data should be ordered by rank, from largest to smallest.

# %%
plt.plot(df['rank'].sort_values(ascending=False), df['area'])

# %%
#What islands are composed of multiple countries?
df[df['countries'].str.contains(",")]
# Out:
#            region                           island    area  \
# 1       Antarctic                        Kerguelen    6200
# 23           Asia                           Borneo  755000
# 45         Europe                          Ireland   84421
# 50         Europe                           Cyprus    9251
# 73  North America                       Hispaniola   76192
# 86        Oceania                       New Guinea  821400
# 98  South America  Isla Grande de Tierra del Fuego   47992
#
#                       countries    climate  rank
# 1       Antarctic Lands, France  temperate    91
# 23  Indonesia, Malaysia, Brunei    tropics     3
# 45      Ireland, United Kingdom  temperate    20
# 50       Cyprus, United Kingdom  temperate    76
# 73    Dominican Republic, Haiti    tropics    23
# 86  Papua New Guinea, Indonesia    tropics     2
# 98             Chile, Argentina  temperate    28
